# %% [markdown]
# # Hello, Seaborn

# %% [markdown]
# [Seaborn](https://seaborn.pydata.org/index.html) is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import pandas as pd

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt

# so we can print in the notebook
# %matplotlib inline
import seaborn as sns

print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# We will be working with a dataset of historical FIFA rankings for six countries: Argentina, Brazil, Spain, France, Germany and Italy.

# %%
# Path of the file
fifa_filepath = "C:/Users/dawre/Desktop/DATA SCIENCE/kaggle/ml-notebook/datasets/fifa.csv"

# Reading the data in the file and creating a DataFrame
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

# %% [markdown]
# * `fifa_filepath` - the file path to the data file
# * `index_col="Date"` - When we load the dataset, we want each entry in the first column to denote a different row. To do this, we set the value of index_col to the name of the first column ("Date", found in cell A1 of the file when it's opened in Excel).
# * `parse_dates=True` - This tells the notebook to understand the each row label as a date (as opposed to a number or other text with a different meaning).

# %% [markdown]
# ## Examine the data

# %%
# print the first 5 rows of the data
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# ## Plot the data

# %% [markdown]
# The code below generates a line chart.

# %%
# Set the width and height of the figure
plt.figure(figsize=(16, 6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Line Charts

# %% [markdown]
# ## Load the Data

# %%
# Path to the file
spotify_filepath = "C:/Users/dawre/Desktop/DATA SCIENCE/kaggle/ml-notebook/datasets/spotify.csv"

# Reading the data and creating the DataFrame
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

# Examine the data
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
# Line chart showing daily global streams of each song
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# set the width and height of the figure
plt.figure(figsize=(14,6))

# add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:title={'center':'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %% [markdown]
# ## Plot a subset of the data

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# The next code cell we will investigate only the first 2 columns.

# %%
plt.figure(figsize=(14,6))

plt.title("Daily Global Streams 2 popular songs in 2017-2018")

sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # Bar Charts and Heatmaps

# %% [markdown]
# ## Load the data
# New dataset `flight_delays.csv`:

# %%
flight_filepath = "C:/Users/dawre/Desktop/DATA SCIENCE/kaggle/ml-notebook/datasets/flight_delays.csv"

# reading the data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

flight_data.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %% [markdown]
# ## Bar chart

# %%
# set the width and height of the figure
plt.figure(figsize=(10,6))

# add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

sns.barplot(x=flight_data.index, y=flight_data['NK'])

plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(14,7))

plt.title("Average Arrival Delay for Each Airline, by Month")

sns.heatmap(data=flight_data, annot=True)

plt.xlabel("Airline")
# Out:
# Text(0.5, 42.0, 'Airline')

# %% [markdown]
# # Scatter Plots

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

print('Setup Complete')
# Out:
# Setup Complete

# %%
import os

insurance_filepath = os.getcwd() + "/datasets/insurance.csv"

insurance_data = pd.read_csv(insurance_filepath)

insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Scatter plots
# To create a **scatter plot** we will use `sns.scatterplot`.
# * the horizontal x-axis (`x = insurance_data['bmi]`)
# * the vertical y-axis (`y = insurance_data['charges']`)

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## Color-coded scatter plots
# We can display the relationship not only between 2 variables but also 3, working with color-coding points.

# %%
sns.scatterplot(x=insurance_data['bmi'], 
    y=insurance_data['charges'],
    hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# We can add another regression line to see the difference between smokers and non-smokers.

# %%
sns.lmplot(x='bmi', y='charges', hue='smoker',
    data = insurance_data)

# %% [markdown]
# Notice that `sns.lmplot()` has a different commands.

# %% [markdown]
# We can adapt the design of scatter plot to feature a categorical variable (like "smoker").

# %%
sns.swarmplot(x=insurance_data['smoker'],
    y=insurance_data['charges'])
# Out:
# c:\Users\dawre\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>
